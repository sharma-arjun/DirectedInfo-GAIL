# %%
% matplotlib inline

import numpy as np
import pandas as pd
import json
import sys
import os
import matplotlib
#matplotlib.use('Agg') 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import seaborn as sns
import pdb
#import ipdb
import h5py
import importlib
import pickle

# Add root folder to sys path
sys.path.append("../")

# %pylab inline
# inline doesn't give interactive plots
# %matplotlib inline 
# %matplotlib notebook
plt.rcParams['figure.figsize'] = (12.0, 12.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'Blues'

sns.set()

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Import own modules
# Need to use importlib since module starts with a numerical value.

# %%
# traj_data_path = '../results/hopper/discrete_vae/batch_64_context_4_no_time/results/results_cp_640_vae_policy.pkl'
traj_data_path = '../results/hopper/discrete_vae/batch_64_context_4_no_time/results/results_cp_640_expert_states.pkl'

traj_data_path = '../results/fetch_pick_and_place/discrete_vae/batch_64_context_2_no_time_cos_similarity_0.0_decay_33e-4_try_2/results_500.pkl'
traj_data_path = '../results/fetch_pick_and_place/state_with_obs_goal_500/discrete_vae/batch_128_context_2_no_time_cos_similarity_0.0_init_5_decay_5e-4_try_1/results_2000.pkl'

# Training with no history
traj_data_path = '../results/fetch_pick_and_place/state_with_obs_goal_500/discrete_vae/hist_1_batch_256_context_2_no_time_cos_similarity_0.0_init_5_decay_5e-4/results_2000.pkl'

# with 3 context
traj_data_path = '../results/fetch_pick_and_place/state_with_obs_goal_500/discrete_vae/hist_1_batch_256_context_2_no_time_cos_similarity_0.0_init_5_decay_5e-4/results_500.pkl'

traj_data = pickle.load(open(traj_data_path, 'rb'))
traj_other_data = None

def visualize_pred_context(pred_context, pred_context_other=None, save_path=None):
    context_values = np.argmax(pred_context, axis=1)
    fig = plt.figure(figsize=(8,8))
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(context_values)
    if pred_context_other is not None:
        ax.plot(np.argmax(pred_context_other, axis=1), 
                color='red', marker='o', linestyle='dashed',
                linewidth=2, markersize=1)
        
    if save_path is not None:
        plt.savefig(save_path, bbox_inches='tight')
    plt.show()

save_path = '../mujoco_results/fetch_pick_and_place'
for i in range(len(traj_data['pred_context'])):
    pred_context = traj_data['pred_context'][i].copy()
    pred_context = np.reshape(pred_context, (pred_context.shape[0], -1))
    if traj_other_data is not None:
        pred_context_other = traj_other_data['pred_context'][i].copy()
        pred_context_other = np.reshape(pred_context_other, (pred_context_other.shape[0], -1))
    path_i = os.path.join(save_path, 'result_{}.pdf'.format(i))
    visualize_pred_context(pred_context, pred_context_other=None, save_path=None)
